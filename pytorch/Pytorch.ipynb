# %% [markdown]
# # Scalars, Vectors, Matrices and Tensors

# %% [markdown]
# # Scalar என்பது ஒற்றை எண்.
#
# **உதாரணமாக
# "3"**

# %% [markdown]
# # Vector  என்பது எண்களின் வரிசை.

# %%
from IPython import display
display.Image("/home/leo/Pictures/Screenshot from 2022-10-15 14-26-05.png")

# %% [markdown]
# # டென்சர் கட்டமைத்தல்

# %%
import torch # டார்ச் தொகுதியை இறக்குமதி செய்கிறது

# %%
a = torch.ones(5) # ஒரு பரிமாணத்தை உருவாக்குகிறது அளவு 5 இன் டென்சர் 1கள் நிரப்பப்பட்டது

# %%
a
# Out:
# tensor([1., 1., 1., 1., 1.])

# %%
a[3]
# Out:
# tensor(1.)

# %%
float(a[3])
# Out:
# 1.0

# %%
a[3] = 2

# %%
a
# Out:
# tensor([1., 1., 1., 2., 1.])

# %%
points = torch.zeros(6)

# %%
points[0] = 1.0
points[1] = 2.0
points[2] = 3.0
points[3] = 4.0
points[4] = 5.0
points[5] = 1.0

# %%
type(points)
# Out:
# torch.Tensor

# %%
points
# Out:
# tensor([1., 2., 3., 4., 5., 1.])

# %%
points[:]
# Out:
# tensor([1., 2., 3., 4., 5., 1.])

# %%
points[:4]
# Out:
# tensor([1., 2., 3., 4.])
